# %%
from utils import *
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
X, y = load_data()

# %%
X.head(2)
# Out:
#    ID  DATE  STOCK  INDUSTRY  INDUSTRY_GROUP  SECTOR  SUB_INDUSTRY     RET_1  \
# 0   0     0      2        18               5       3            44 -0.015748
# 1   1     0      3        43              15       6           104  0.003984
#
#    VOLUME_1     RET_2  VOLUME_2     RET_3  VOLUME_3     RET_4  VOLUME_4  \
# 0  0.147931 -0.015504  0.179183  0.010972  0.033832 -0.014672 -0.362868
# 1       NaN -0.090580       NaN  0.018826       NaN -0.025540       NaN
#
#       RET_5  VOLUME_5     RET_6  VOLUME_6     RET_7  VOLUME_7     RET_8  \
# 0  0.016483  -0.97292  0.014331   0.59081 -0.017215  0.557246 -0.018433
# 1 -0.038062       NaN -0.006873       NaN -0.026756       NaN  0.023973
#
#    VOLUME_8     RET_9  VOLUME_9    RET_10  VOLUME_10   RET_11  VOLUME_11  \
# 0   0.45359  0.134146  8.580442  0.182287   3.427303  0.01357  -0.328418
# 1       NaN  0.158731       NaN  0.045642        NaN -0.00823        NaN
#
# ...

# %%
y.head(2)
# Out:
#    ID   RET
# 0   0  True
# 1   1  True
